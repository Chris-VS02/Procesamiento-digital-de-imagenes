# %% [markdown]
# # CONVERSIÓN ENTRE MODELOS DE COLOR

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen en BGR
image_bgr = cv2.imread('SEAH.jpg')

# %% [markdown]
# ## BGR -> RGB

# %%
# Convertir de BGR a RGB
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Mostrar la imagen en RGB
plt.imshow(image_rgb)
plt.title('Imagen en RGB')
plt.axis('off')
plt.show()

# %% [markdown]
# l modelo RGB es uno de los modelos más comunes y se utiliza principalmente en pantallas y dispositivos electrónicos.
#
# Aplicaciones en Machine Learning:
# Clasificación de imágenes: Usado ampliamente en tareas de clasificación de imágenes, donde el color es una característica importante para distinguir entre diferentes clases.
# Reconocimiento de objetos: Se utiliza para entrenar modelos que reconocen objetos basándose en su color y características visuales.
# Redes neuronales convolucionales (CNN): Las imágenes en RGB son la entrada estándar para redes convolucionales en la mayoría de los casos, ya que los datos son directamente legibles para los modelos.
# Ejemplo:
# Clasificación de imágenes en categorías como "frutas", "animales", etc., basándose en colores visibles.

# %% [markdown]
# ### BGR -> GRAYSCALE

# %%
# Convertir de BGR a Escala de Grises
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

# Mostrar la imagen en Escala de Grises
plt.imshow(image_gray, cmap='gray')
plt.title('Imagen en Escala de Grises')
plt.axis('off')
plt.show()

# %% [markdown]
# El modelo de escala de grises reduce las imágenes a una sola componente de luminancia, eliminando la información de color.
#
# Aplicaciones en Machine Learning:
# Detección de bordes y contornos: La escala de grises se usa a menudo como preprocesamiento en algoritmos de detección de bordes (por ejemplo, Canny Edge Detection), porque la luminancia es más importante que el color para estas tareas.
# Reconocimiento de caracteres (OCR): Para tareas como el reconocimiento de texto o números, se prefiere trabajar con imágenes en escala de grises.
# Segmentación de imágenes: En algunos casos, se prefiere trabajar con imágenes en escala de grises para simplificar la segmentación, ya que se reduce la complejidad computacional.
# Ejemplo:
# OCR (Reconocimiento óptico de caracteres) en documentos en blanco y negro.

# %% [markdown]
# ### BGR -> HSV

# %%
# Convertir de BGR a HSV
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)

# Mostrar la imagen en HSV
plt.imshow(image_hsv)
plt.title('Imagen en HSV')
plt.axis('off')
plt.show()

# %% [markdown]
# El modelo HSV es más intuitivo porque separa el matiz (color) de la luminosidad, lo que lo hace útil para tareas basadas en el color.
#
# Aplicaciones en Machine Learning:
# Segmentación de colores: Dado que el matiz (H) está relacionado con el color, es fácil segmentar colores específicos, como el rojo, verde, azul, etc.
# Detección de objetos: El modelo HSV es útil cuando se necesita detectar objetos que tienen un color específico, independientemente de la iluminación.
# Reconocimiento de patrones de color: En aplicaciones como la detección de señales de tráfico, donde el color es un atributo clave.
# Ejemplo:
# Detección de objetos de un color específico (como rojos, verdes, azules) en imágenes, independientemente de la variabilidad en la luz.

# %% [markdown]
# ## BGR -> LAB

# %%
# Convertir de BGR a LAB
image_lab = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2LAB)

# Mostrar la imagen en LAB
plt.imshow(image_lab)
plt.title('Imagen en LAB')
plt.axis('off')
plt.show()

# %% [markdown]
# El modelo LAB es un espacio de color perceptual que intenta ser independiente de los dispositivos y se basa en cómo los humanos perciben el color.
#
# Aplicaciones en Machine Learning:
# Segmentación de imágenes: Dado que LAB está diseñado para imitar la percepción humana del color, se puede usar en la segmentación de imágenes donde los detalles de color no se capturan bien con otros modelos como RGB.
# Mejora de imágenes: El canal de luminancia (L) es útil para mejorar la calidad visual de las imágenes, ya que la mayoría de las operaciones visuales dependen de la luminancia más que del color.
# Reconocimiento de patrones: LAB es útil para reconocer patrones que dependen de la percepción humana del color, como la identificación de defectos en productos.
# Ejemplo:
# Detección de defectos en imágenes (por ejemplo, inspección de calidad en fabricación de productos), donde el color puede variar ligeramente pero el contraste y la luminancia siguen siendo claves.

# %% [markdown]
# ## BGR ->YCrCb

# %%
# Convertir de BGR a YCrCb
image_ycrcb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2YCrCb)

# Mostrar la imagen en YCrCb
plt.imshow(image_ycrcb)
plt.title('Imagen en YCrCb')
plt.axis('off')
plt.show()

# %% [markdown]
# El modelo YCrCb separa la luminancia (Y) de las componentes cromáticas (Cr, Cb), y es utilizado principalmente en la compresión de video.
#
# Aplicaciones en Machine Learning:
# Compresión de imágenes y videos: Debido a que la luminancia (Y) tiene más peso que la crominancia (Cr, Cb), es útil en la compresión de imágenes y videos (como en formatos de video como MPEG).
# Análisis de video en tiempo real: Utilizado en análisis de movimiento y seguimiento de objetos, ya que separa los componentes de luminosidad de la crominancia, lo que permite un mejor procesamiento y seguimiento en condiciones de diferentes iluminaciones.
# Ejemplo:
# Compresión de imágenes y videos en tareas como la transmisión de video en streaming

# %% [markdown]
# ### BGR -> HLS

# %%
# Convertir de BGR a HLS
image_hls = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HLS)

# Mostrar la imagen en HLS
plt.imshow(image_hls)
plt.title('Imagen en HLS')
plt.axis('off')
plt.show()

# %% [markdown]
# ´El modelo HLS es similar al HSV, pero con la componente de luminosidad separada, lo que lo hace útil para ciertas transformaciones de color.
#
# Aplicaciones en Machine Learning:
# Mejora de imágenes: La separación de la componente de luminosidad permite realizar ajustes específicos en la luz sin alterar los colores de la imagen, útil para tareas de mejora de imágenes en condiciones de iluminación variables.
# Reconocimiento de color en imágenes: Es útil cuando se necesita analizar la intensidad de un color y su saturación independientemente de su tonalidad.
# Ejemplo:
# Ajuste de brillo y saturación en la mejora de la calidad de las imágenes para tareas de reconocimiento.´

# %% [markdown]
# RGB ->BGR

# %%
# Convertir de RGB a BGR
image_bgr_converted = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

# Mostrar la imagen convertida a BGR
plt.imshow(cv2.cvtColor(image_bgr_converted, cv2.COLOR_BGR2RGB))
plt.title('Imagen convertida a BGR')
plt.axis('off')
plt.show()
